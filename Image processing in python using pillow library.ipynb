# %% [markdown]
# # <font color='green'>IMAGE PROCESSING IN PYTHON USING PILLOW LIBRARY:</f>

# %%
from PIL import Image
import os, sys
from PIL import ImageColor
#import cv2
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from matplotlib import cm
from PIL import Image, ImageSequence
from PIL import Image, ImageDraw, ImageFont
import sys
import qrcode
from PIL import ImageEnhance
from PIL import Image, ImageDraw, ImageFilter
path=input('\nEnter Image Name\n(In image.jpg or image.png format) = ')
img=Image.open(path)
print('       !! WELCOME TO IMAGE PROCESSING !!     ')
print('1.Show Image')
print('2.Show Image Size')
print('3.Show Image Format')
print('4.Show Image Mode')
print('5.Change format of Image')
print('6.Change color of image')
print('7.Colormap filter')
print('8.Create Thumbnail')
print('9.Crop Image')
print('10.Rotate Image')
print('11.Resize Image')
print('12.Transpose of Image')
print('13.Create Image')
print('14.Draw Shapes')
print('15.Copying and pasting of Image')
print('16.Crop and paste image')
print('17.Composite of two image')
print('18.Add margins')
print('19.Generate QR code of Image')
print('20.Concatenate image')
print('21.Splitting and merging bands')
print('22.Converting modes')
print('23.Apply Filter')
print('24.Image enhancement')
print('25.Reading sequences')
print('26.Watermark')
n=int(input('Enter corresponding serial Number= '))
if n==1: 
    img.show()
elif n==2:
    
    print('size=',img.size)
elif n==3:
    
    print('format=',img.format)
elif n==4:
    
    print('mode=',img.mode)
elif n==5:
    print('  !! change format of Image !!  ')
    img.save('new.png')
    new=Image.open('new.png')
    print('Format=',new.format)
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
          img.save('changeformat.jpg')
          print('Image is successfully saved as  changeformat.jpg')
elif n==6:
    print('   !! CHANGE COLOR OF IMAGE !!  ')
    print('1.Grayscale')
    print('2.Black and White')
    print('3.Color')
    a=int(input('Enter corresponding serial Number= '))

    if a==1:
          greyscale_image = img.convert('L')
          greyscale_image.show()
          print('Do you want to save this image?')
          print('1.Yes')
          print('2.No')
          s=int(input('Enter corresponding serial Number='))
          if s==1:
             #greyscale_image.save('greyscale_image.jpg')
             print('Image is successfully saved as greyscale_image.jpg')
    elif a==2:
          BW_image = img.convert('1')
          BW_image.show()
          print('Do you want to save image?')
          print('1.Yes')
          print('2.No')
          s=int(input('Enter corresponding serial Number='))
          if s==1:
             BW_image.save('BW_image.jpg')
             print('Image is successfully saved as BW_image.jpg')
    else:
          color_image = img.convert('RGB')
          color_image.show()
          print('Do you want to save this image?')
          print('1.Yes')
          print('2.No')
          s=int(input('Enter corresponding serial Number='))
          if s==1: 
            #color_image.save('color.jpg')
             print('Image is successfully saved as color.jpg')
          
elif n==7:
    print('  !! Apply colormap filter !!  ')
    print('\nMENU:\n 1. Accent\n 2. Accent_r\n 3. Blues\n 4. Blues_r\n 5. BrBG\n 6. BrBG_r\n 7. BuGn\n 8. BuGn_r\n 9. BuPu\n 10. BuPu_r\n 11. CMRmap\n 12. CMRmap_r\n 13. Dark2\n 14. Dark2_r\n 16. GnBu\n 17. GnBu_r\n 18. Greens\n 19. Greens_r\n 20. Greys\n 21. Greys_r\n 22. OrRd\n 23. Oranges\n 24. Reds\n 25. Blues ')    
    plt.figure(figsize=[20,15])
    img=mpimg.imread(path)
    lum_img=img[:,:,0]
    x=input('Enter corresponding filter Name=')
    plt.imshow(lum_img,x)
    plt.title(x,fontsize=25)
    plt.savefig('filter_image.jpg')
    
    
elif n==8:
    print('  !! Create Thumbnail !!  ')
    Width=int(input('Enter width of image='))
    Height=int(input('Enter Height of image='))
    img.thumbnail((Width, Height))
    img.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
        img.save('Thumbnail.jpg')
        print('Image is successfully saved as Thumbnail.jpg')
    
elif n==9:
    print(' !! Crop Image  !! ')
    left=int(input('Enter left image size='))
    upper=int(input('Enter upper image size='))
    right=int(input('Enter right image size='))
    lower=int(input('Enter lower image size='))
    box = (left, upper, right,lower )    #700, 100, 1000, 500
    cropped_image = img.crop(box)
    cropped_image.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
        cropped_image.save('cropped_image.jpg')
        print('Image is successfully saved as cropped_image.jpg')
elif n==10:
    print(' !! Rotate Image  !! ')
    x=int(input('Enter angle of rotation='))
    image_rot = img.rotate(x)
    image_rot.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
        image_rot.save('image_rotate.jpg')
        print('Image is successfully saved as image_rotate.jpg')
elif n==11:
    print(' !! Resize !! ')
    width=int(input('Enter width of Image='))
    height=int(input('Enter height of Image='))
    image4 = img.resize((width,height))
    #image4.save('resize.jpg')
    image4.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
        image4.save('resize.jpg')
        print('Image is successfully saved as resize.jpg')
elif n==12:
    print(' !! Transpose of Image  !! ')
    print('1.FLIP_LEFT_RIGHT')
    print('2.FLIP_TOP_BOTTOM')
    print('3.ROTATE_90')
    print('4.ROTATE_180')
    print('5.ROTATE_270')
    p=int(input('Enter corresponding serial Number ='))
    if p==1:
        i1 = img.transpose(Image.FLIP_LEFT_RIGHT)
        #i1.save('i1.jpg')
        i1.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            i1.save('FLIP_LEFT_RIGHT.jpg')
            print('Image is successfully saved as FLIP_LEFT_RIGHT.jpg')
    if p==2:
        i2 = img.transpose(Image.FLIP_TOP_BOTTOM)
        #i2.save('i2.jpg')
        i2.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            i2.save('FLIP_TOP_BOTTOM.jpg')
            print('Image is successfully saved as FLIP_TOP_BOTTOM.jpg')
    if p==3: 
        i3 = img.transpose(Image.ROTATE_90)
        #i3.save('i3.jpg')
        i3.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            i3.save('ROTATE_90ROTATE_90.jpg')
            print('Image is successfully saved as ROTATE_90.jpg')
    if p==4:
        i4 = img.transpose(Image.ROTATE_180)
        #i4.save('i4.jpg')
        i4.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            i4.save('ROTATE_180.jpg')
            print('Image is successfully saved as ROTATE_180.jpg')
    if p==5:
        i5 = img.transpose(Image.ROTATE_270)
        #i5.save('i5.jpg')
        i5.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            i5.save('ROTATE_270.jpg')
            print('Image is successfully saved as ROTATE_270.jpg')
    
elif n==13:
    print(' !! Create Image !! ')
    print('\nMENU:\n 1.Black\n 2. White\n 3. Red\n 4. Lime\n 5. Blue\n 6. Yellow\n 7. Cyan\n 8. Magneta\n 9. Silver\n 10. Gray\n 11. Maroon\n 12. olive\n 13. green\n 14. purple\n 15. teal')
    
    x=input('Enter Color Name = ')
    width=int(input('Enter width of image='))
    height=int(input('Enter height of image='))
    im = Image.new('RGBA', (width, height), x)
    im.show()
    #im.save('purpleImage.png')
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
            im.save('newimage.jpg')
            print('Image is successfully saved as newimage.jpg')
elif n==14:
    print(' !! Draw Shapes !! ')
    print('1.Ellipse')
    print('2.Rectangle')
    print('3.Line')
    print('4.Polygon')
    b=int(input('Enter corresponding serial Number ='))
    img1 = Image.new('RGB', (600, 300), (128, 128, 128))
    draw = ImageDraw.Draw(img1)
    if b==1:
        draw.ellipse((100, 100, 150, 200), fill=(255, 0, 0), outline=(0, 0, 0))
        img1.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            img1.save('ellipse.jpg')
            print('Image is successfully saved as ellipse.jpg')
        
    if b==2:
        draw.rectangle((200, 100, 300, 200), fill=(0, 192, 192), outline=(255, 255, 255))
        img1.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            img1.save('rectangle.jpg')
            print('Image is successfully saved as rectangle.jpg')
       
    if b==3:
        draw.line((350, 200, 450, 100), fill=(255, 255, 0), width=5)
        img1.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            img1.save('line.jpg')
            print('Image is successfully saved as lne.jpg')
       
    if b==4:
        draw.polygon(((200, 200), (300, 100), (250, 50)), fill=(255, 255, 0), outline=(0, 0, 0))
        img1.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            img1.save('polygon.jpg')
            print('Image is successfully saved as polygon.jpg')

elif n==15:
    print(' !! copy and paste of image !! ')
    path1=input('Enter  image1 name\n(in image.jpg or image.png format) = ')
    image1 = Image.open(path1)
    path2=input('Enter image name to be pasted in image1\n(in image.jpg or image.png format) =')
    image2 = Image.open(path2)
    image1.paste(image2,(90,60))
    image1.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
            image1.save('newimage.jpg')
            print('Image is successfully saved as newimage.jpg')
elif n==16:
    print(' !! Crop and paste image !! ')
    crop=input('Enter image name to be cropped\n(in image.jpg or image.png format) =')
    left=int(input('Enter left image size='))
    upper=int(input('Enter upper image size='))
    right=int(input('Enter right image size='))
    lower=int(input('Enter lower image size='))
    box = (left, upper, right,lower )    #700, 100, 1000, 500 
    img1=Image.open(crop)
    cropped_image = img1.crop(box)
    cropped_image.save('cropped_image.jpg')
    img2=Image.open('cropped_image.jpg')
    img.paste(img2,(0,0))
    #img.save('c.jpg')
    img.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
            img.save('newimage1.jpg')
            print('Image is successfully saved as newimage1.jpg')
elif n==17:
    print(' !! Composite of two images !! ')
    path1=input('Enter image1 name\n(in image.jpg or image.png format)=')
    im1 = Image.open(path1)
    path2=input('Enter image2 name\n(in image.jpg or image.png format)=')
    im2 = Image.open(path2).resize(im1.size)
    mask = Image.new("L", im1.size, 128)
    im = Image.composite(im1, im2, mask)
    im.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
            im.save('newimage2.jpg')
            print('Image is successfully saved as newimage2.jpg')
elif n==18:
    print(' !! Add margins to Image !! ')
    def add_margin(pil_img, top, right, bottom, left, color):
        width, height = pil_img.size
        new_width = width + right + left
        new_height = height + top + bottom
        result = Image.new(pil_img.mode, (new_width, new_height), color)
        result.paste(pil_img, (left, top))
        return result
    left=int(input('Enter left image size='))
    upper=int(input('Enter upper image size='))
    right=int(input('Enter right image size='))
    lower=int(input('Enter lower image size='))
    print('\nMENU\n1-red,\n2-blue\n3-green\n4-choclate\n5-white\n6-cyan')
    c=int(input('Enter corresponding serial Number='))
    if c==1:
        im_new = add_margin(img, left, upper,right, lower, (255, 0, 0, 255))
        #im_new.save('margins.jpg')
        im_new.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            im_new.save('newimage3.jpg')
            print('Image is successfully saved as newimage3.jpg')
        
    if c==2:
        im_new = add_margin(img, left, upper,right, lower,(0, 0, 255, 255))
        #im_new.save('margins.jpg')
        im_new.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            im_new.save('newimage3.jpg')
            print('Image is successfully saved as newimage3.jpg')
    if c==3:
        im_new = add_margin(img, left, upper,right, lower,(0, 128, 0, 255))
        #im_new.save('margins.jpg')
        im_new.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            im_new.save('newimage3.jpg')
            print('Image is successfully saved as newimage3.jpg')
    if c==4:
         im_new = add_margin(img, left, upper,right, lower,(100, 149, 237, 255))
         #im_new.save('margins.jpg')
         im_new.show()
         print('Do you want to save this image?')
         print('1.Yes')
         print('2.No')
         s=int(input('Enter corresponding serial Number='))
         if s==1:
             im_new.save('newimage3.jpg')
             print('Image is successfully saved as newimage3.jpg')
    if c==5:
         im_new = add_margin(img, left, upper,right, lower,(255,255,255, 255))
         #im_new.save('margins.jpg')
         im_new.show()
         print('Do you want to save this image?')
         print('1.Yes')
         print('2.No')
         s=int(input('Enter corresponding serial Number='))
         if s==1:
              im_new.save('newimage3.jpg')
              print('Image is successfully saved as newimage3.jpg')
    if c==6:
        im_new = add_margin(img, left, upper,right, lower,(0,255,255, 255))
        #im_new.save('margins.jpg')
        im_new.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            im_new.save('newimage3.jpg')
            print('Image is successfully saved as newimage3.jpg')
    
elif n==19:
    print(' !! Generate QR code Image !! ')
    img = qrcode.make(path)
    print(type(img))
    print(img.size)
    #img.save('qrcode.jpg')
    img.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
            img.save('qrcode.jpg')
            print('Image is successfully saved as qrcode.jpg')
elif n==20:
    print(' !! Concatenate image !!')
    path1=input('Enter image1 name\n(in image.jpg or image.png format) =')
    im1=Image.open(path1)
    path2=input('Enter image2 name\n(in image.jpg or image.png format) =')
    im2=Image.open(path2)
    def get_concat_h(im1, im2):
        dst = Image.new('RGB', (im1.width + im2.width, im1.height))
        dst.paste(im1, (0, 0))
        dst.paste(im2, (im1.width, 0))
        return dst
    get_concat_h(im1, im2).show()

    def get_concat_v(im1, im2):
        dst = Image.new('RGB', (im1.width, im1.height + im2.height))
        dst.paste(im1, (0, 0))
        dst.paste(im2, (0, im1.height))
        return dst
    get_concat_v(im1, im2).show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
             get_concat_h(im1, im1).save('pillow_concat_h.jpg')
             get_concat_v(im1, im1).save('pillow_concat_v.jpg')
             print('Image is successfully saved as newimage3.jpg')
    
elif n==21:
    print(' !! Splitting and merging bands !!')
    image=Image.open(path)
    r, g, b = image.split()
    img3 = Image.merge("RGB", (b, r, b))
    img3.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
            img3.save('newimage5.jpg')
            print('Image is successfully saved as newimage5.jpg')
    
elif n==22:
    print(' !! Converting modes !!')
    print('\nMode\n1- 1\n2- L \n3- P\n4- RGB\n5- RGBA\n6- CMYK\n7- YCBCR\n8- LAB\n9- HSV\n10- I')
    x=input('Enter corresponding mode Name = ')
    img4= Image.open(path).convert(x)
    img4.show()
    print('Do you want to save this image?')
    print('1.Yes')
    print('2.No')
    s=int(input('Enter corresponding serial Number='))
    if s==1:
            img4.save('newimage6.jpg')
            print('Image is successfully saved as newimage6.jpg')
elif n==23:
    print(' !! Apply Filter !!')
    print('\nFILTER MENU:\n1- BLUR\n2- CONTOUR\n3- DETAIL\n4- EDGE_ENHANCE\n5- EDGE_ENHANCE_MORE\n6- EMBOSS\n7- FIND_EDGES\n8- SMOOTH\n9- SMOOTH_MORE\n10- SHARPEN')
    d=int(input('Enter corresponding serial Number='))
    if d==1:
        out = img.filter(ImageFilter.BLUR)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter1.jpg')
            print('Image is successfully saved as filter1.jpg')
    if d==2:
        out = img.filter(ImageFilter.CONTOUR)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter2.jpg')
            print('Image is successfully saved as filter2.jpg')
    if d==3:
        out = img.filter(ImageFilter.DETAIL)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter3.jpg')
            print('Image is successfully saved as filter3.jpg')
    if d==4:
        out = img.filter(ImageFilter.EDGE_ENHANCE)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter4.jpg')
            print('Image is successfully saved as filter4.jpg')
    if d==5:
        out = img.filter(ImageFilter.EDGE_ENHANCE_MORE)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter5.jpg')
            print('Image is successfully saved as filter5.jpg')
    if d==6:
        out = img.filter(ImageFilter.EMBOSS)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter6.jpg')
            print('Image is successfully saved as filter6.jpg') 
    if d==7:
        out = img.filter(ImageFilter.FIND_EDGES)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter7.jpg')
            print('Image is successfully saved as filter7.jpg')
    if d==8:
        out = img.filter(ImageFilter.SMOOTH)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter8.jpg')
            print('Image is successfully saved as filter8.jpg')
    if d==9:
        out = img.filter(ImageFilter.SMOOTH_MORE)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter9.jpg')
            print('Image is successfully saved as filter9.jpg')
    if d==10:
        out = img.filter(ImageFilter.SHARPEN)
        out.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            out.save('filter10.jpg')
            print('Image is successfully saved as filter10.jpg')
elif n==24:
    print(' !! Image Enhancement !!')
    print('\nMENU:\n1-Contrast\n2-Color\n3-Brightness\n4-Sharpness')
    e=int(input('Enter corresponding serial Nmber='))
    if e==1:
        enh = ImageEnhance.Contrast(img)
        x=float(input('Enter level of contrast (1.0 to 10.0) = '))
        #enh3.enhance(x).save('enh.jpg')
        enh.enhance(x).show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            enh.enhance(x).save('enh1.jpg')
            print('Image is successfully saved as enh1.jpg')
  
    if e==2:
        enh = ImageEnhance.Color(img)
        x=float(input('Enter level of color (1.0 to 10.0) = '))
        #enh3.enhance(x).save('enh.jpg')
        enh.enhance(x).show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            enh.enhance(x).save('enh2.jpg')
            print('Image is successfully saved as enh2.jpg')
    if e==3:
        enh = ImageEnhance.Brightness(img)
        x=float(input('Enter level of Brightness (1.0 to 10.0) = '))
        #enh3.enhance(x).save('enh.jpg')
        enh.enhance(x).show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            enh.enhance(x).save('enh3.jpg')
            print('Image is successfully saved as enh3.jpg')
    if e==4:
        enh = ImageEnhance.Sharpness(img)
        x=float(input('Enter level of Sharpness (1.0 to 10.0) = '))
        #enh3.enhance(x).save('enh.jpg')
        enh.enhance(x).show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            enh.enhance(x).save('enh4.jpg')
            print('Image is successfully saved as enh4.jpg')

elif n==25:
    print('  !! Reading sequences !!  ')
    print('NOTE = Applicable Only for GIF')
    index =1
    img=input('Enter gif Name =')
    img=Image.open(img)
    for frame in ImageSequence.Iterator(img):
            frame.save("frame%d.png" % index)
            frame.show()
            index = index + 1 
elif n==26:
    
    print('  !! CREATE  WATERMARK !!  ')
    
    print('1. Image Watermark\n2. Name Watermark')
    f=int(input('Enter corresponding serial Number= '))
    if f==1:
    #path=input('Enter Image name=')
    #image = Image.open(path)
        logo=input('Enter logo Image name=')
        logo = Image.open(logo).convert("RGBA")
        image_copy = img.copy()
        position = ((image_copy.width - logo.width), (image_copy.height - logo.height))
        image_copy.paste(logo, position, logo)
        #image_copy.save('logo.jpg')
        image_copy.show()
        image_copy.paste(logo, position, logo)
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            image_copy.save('imagelogo.jpg')
            print('Image is successfully saved as logo1.jpg')
    if f==2:
        idraw = ImageDraw.Draw(img)
        width, height = img.size
        x="Shot on realme 3 pro\nBy "
        y=input('Enter Owner Name=' )
        text=x+y
        print(text)
        font = ImageFont.truetype('arial.ttf', 36)
        textwidth, textheight = idraw.textsize(text, font)
        margin = 10
        w = width - textwidth - margin
        h = height - textheight - margin
        idraw.text((w, h), text, font=font) 
        #img.save('watermarked.png')
        img.show()
        print('Do you want to save this image?')
        print('1.Yes')
        print('2.No')
        s=int(input('Enter corresponding serial Number='))
        if s==1:
            rgb_im = img.convert('RGB')
            rgb_im.save('textlogo.jpg')
            print('Image is successfully saved as logo2.jpg')
            
else:
    print('Enter corresponding serial Number properly')
# Out:
# Enter Image Name
# (In image.jpg or image.png format) = sar.png
#        !! WELCOME TO IMAGE PROCESSING !!
# 1.Show Image
# 2.Show Image Size
# 3.Show Image Format
# 4.Show Image Mode
# 5.Change format of Image
# 6.Change color of image
# 7.Colormap filter
# 8.Create Thumbnail
# 9.Crop Image
# 10.Rotate Image
# 11.Resize Image
# 12.Transpose of Image
# 13.Create Image
# 14.Draw Shapes
# 15.Copying and pasting of Image
# 16.Crop and paste image
# 17.Composite of two image
# 18.Add margins
# 19.Generate QR code of Image
# 20.Concatenate image
# 21.Splitting and merging bands
# 22.Converting modes
# 23.Apply Filter
# 24.Image enhancement
# 25.Reading sequences
# 26.Watermark
# Enter corresponding serial Number= 26
#   !! CREATE  WATERMARK !!
# 1. Image Watermark
# 2. Name Watermark
# Enter corresponding serial Number= 2
# Enter Owner Name=sarwar
# ...
